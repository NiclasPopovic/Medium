# %%
import os
import random 
import pandas as pd
import numpy as np
import pytz
from statsmodels.tsa.seasonal import STL
from matplotlib import figure, pyplot as plt
from sklearn.metrics import mean_squared_error
from statsmodels.tsa.exponential_smoothing.ets import ETSModel

# %%
## These are my default settings for plots

plt.rcParams["font.family"] = "Times New Roman"
plt.rc("xtick",labelsize=12)
plt.rc("ytick",labelsize=12)
plt.rcParams["figure.figsize"] = (20,8)
plt.rcParams.update({'font.size': 18})
plt.rcParams.update({'xtick.labelsize': 18})
plt.rcParams.update({'ytick.labelsize': 18})

# %% [markdown]
# # Functions

# %%
# Function for reproducible results
def set_seed(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    random.seed(seed)

# %%
# Forecast Accuracy Metric
def MAPE(df,column_actual,column_predicted):
    mask1 = df[column_actual] != 0
    df = df[mask1]
    y_true, y_pred = np.array(df[column_actual].values), np.array(df[column_predicted].values)
    mape = np.mean(np.abs((y_true - y_pred) / y_true)) * 100
    return mape

# %%
def RMSE(df,column_actual,column_predicted):
    mask1 = df[column_actual] != 0
    df = df[mask1]
    rmse = mean_squared_error(df[column_actual], df[column_predicted], squared=False)
    return rmse

# %%
# This function creates the population matrix from which we will draw randomly blocks of the size=24 (default).
# Each row represents one block of the size 24
# Matrix shape: # number of blocks (281) x block size (24)

def build_matrix(df,size=24):
    n = len(df_training)
    block_size = size
    maximum_number_of_blocks = n-block_size+1
    population_matrix = np.zeros(shape=(block_size,maximum_number_of_blocks), dtype=float)
    for i in range(0,maximum_number_of_blocks):
        population_matrix[:,i] = df['residuals'][i:i+block_size].values
    population_matrix = population_matrix.T
    return population_matrix

# %%
# This function draws randomly from the population matrix and returns the desired number of 
# bootstrapped residuals time series

def bootstrapping_residuals(df_train,number_of_bootstrapped_series=10,size=24):
    set_seed(100)
    n = len(df_train)
    block_size = size
    maximum_number_of_blocks = n-block_size+1
    number_of_drafts = int(n/block_size)

    bootstrapped_single_time_series = []
    bootstrapped_collection_time_series = []
    sample = 0
    population_matrix = build_matrix(df_train)
    # number_of_drafts = # of Drafts for each bootstrapped time series
    # number_of_bootstrapped_series = # of series that will be bootstrapped
    for j in range(0,number_of_bootstrapped_series):
        bootstrapped_single_time_series = []
        for i in range(0,number_of_drafts+2):
        # inner loop to draft blocks for time series j
        # here we draft each draft i a random block (size 24) from the population matrix
            random_series_draft = np.random.randint(0,maximum_number_of_blocks)
            sample = population_matrix[random_series_draft,:]
            # After the last iteration in the inner loop 
            # bootstrapped_single_time_series is a bootstrapped time series that 
            bootstrapped_single_time_series.append(sample)
        bootstrapped_collection_time_series.append(bootstrapped_single_time_series)
    return bootstrapped_collection_time_series

# %%
def build_bootstrapped_df(bootstrapped_series,df_training_data,size=24):
    set_seed(100)
    temp_series = []
    block_size = size
    for i in range(0,len(bootstrapped_series)):
        temp_series.append(np.concatenate(bootstrapped_series[i]))

        # discard random number of values between 0 and block_size - 1 at the beginning
        number_of_elements_to_remove = np.random.randint(0,block_size-1)
        temp_series[i] = temp_series[i][number_of_elements_to_remove:]

        # Discard all elements after the last element of the original training series
        if len(temp_series[i]) > len(df_training_data):
            temp_series[i] = temp_series[i][:len(df_training_data)]   
        temp_series[i] = temp_series[i].reshape(-1,1)
    #    temp_series[i] = temp_series[i] + df_training['trend'].values + df_training['seasonality'].values

    # Create dataframe
    df = pd.DataFrame(np.array(temp_series).tolist())
    df = df.T
    for i in range(0,len(df.columns)):
        df[i] = df[i].str[0] 
    df.columns = ['bootstrapped_series_' + str(col) for col in df.columns]
    df.index = df_training_data.index
    df.asfreq('MS')
    return df

# %% [markdown]
# # Data Exploration

# %%
# Read the date and rename the column for convenience reasons
df = pd.read_csv('01 Kaggle/Alcohol_Sales.csv',sep=',')
df.rename({'S4248SM144NCEN':'sales'},axis=1,inplace = True)

# %%
df['DATE'] = pd.to_datetime(df['DATE'],format='%Y-%m-%d')

# %%
df.index = df['DATE']
df = df.drop('DATE',axis=1)

# %%
df.asfreq('MS')
# Out:
#             sales
# DATE
# 1992-01-01   3459
# 1992-02-01   3458
# 1992-03-01   4002
# 1992-04-01   4564
# 1992-05-01   4221
# ...           ...
# 2018-09-01  12396
# 2018-10-01  13914
# 2018-11-01  14174
# 2018-12-01  15504
# 2019-01-01  10718
#
# [325 rows x 1 columns]

# %%
#delet last data point to have a consistent dataset
df = df[:len(df)-1]

# %%
df['sales'].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
df[-36:]['sales'].plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %%
# Both mean and variance are not perfectly constant but it should be 'good enough' 
# Additional test could be applied (ADF, KPSS, CH, etc.) but for illustration this should be fine

np.log(df).plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# # Baseline model

# %%
# split the data into training and test data
training_index = len(df)-12
df_training = df[:training_index].copy()
df_training = np.log(df_training)
df_test= df[training_index:].copy()

# %%
model = ETSModel(df_training['sales'],error='add',trend='add',seasonal='add',seasonal_periods=12)
model = model.fit()
y_hat = model.forecast(steps=12)
# Important: calculate the exponential of all predictions to transform the forecast back to the original scale
y_hat = np.exp(y_hat)
df_test['ETS_baseline'] = y_hat
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.30985D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -8.64106D-01    |proj g|=  1.12699D+01
#
# At iterate    2    f= -1.18670D+00    |proj g|=  5.82147D+00
#
# At iterate    3    f= -1.29859D+00    |proj g|=  2.59158D+00
#
# At iterate    4    f= -1.35378D+00    |proj g|=  1.94922D+00
#
# At iterate    5    f= -1.38336D+00    |proj g|=  1.30028D+00
#
# At iterate    6    f= -1.45182D+00    |proj g|=  3.16371D-01
#
# At iterate    7    f= -1.47747D+00    |proj g|=  2.30122D-01
#
# At iterate    8    f= -1.49485D+00    |proj g|=  9.97083D-01
#
# At iterate    9    f= -1.50008D+00    |proj g|=  6.84034D-01
#
# At iterate   10    f= -1.50617D+00    |proj g|=  9.95182D-01
#
# At iterate   11    f= -1.51149D+00    |proj g|=  1.49759D-01
#
# At iterate   12    f= -1.51695D+00    |proj g|=  7.79108D-01
#
# At iterate   13    f= -1.52598D+00    |proj g|=  9.64578D-01
#
# At iterate   14    f= -1.54408D+00    |proj g|=  9.19528D-01
#
# At iterate   15    f= -1.56803D+00    |proj g|=  1.01364D+00
#
# At iterate   16    f= -1.57895D+00    |proj g|=  2.37461D+00
#
# At iterate   17    f= -1.58244D+00    |proj g|=  2.22235D-01
#
# At iterate   18    f= -1.58418D+00    |proj g|=  1.38244D-01
#
# At iterate   19    f= -1.58689D+00    |proj g|=  2.35252D-01
#
# At iterate   20    f= -1.59286D+00    |proj g|=  1.78364D-01
#
# At iterate   21    f= -1.60057D+00    |proj g|=  1.30677D+00
#
# At iterate   22    f= -1.60449D+00    |proj g|=  1.01137D+01
#
# At iterate   23    f= -1.60716D+00    |proj g|=  2.48192D+00
#
# At iterate   24    f= -1.60826D+00    |proj g|=  6.46446D-02
#
# At iterate   25    f= -1.60856D+00    |proj g|=  2.12962D-01
#
# At iterate   26    f= -1.60871D+00    |proj g|=  3.41628D-02
#
# At iterate   27    f= -1.60877D+00    |proj g|=  3.42389D-02
#
# At iterate   28    f= -1.60884D+00    |proj g|=  9.99630D-02
#
# At iterate   29    f= -1.60915D+00    |proj g|=  2.51814D-01
#
# At iterate   30    f= -1.60953D+00    |proj g|=  2.31062D-01
#
# At iterate   31    f= -1.61051D+00    |proj g|=  1.49735D-01
#
# At iterate   32    f= -1.61227D+00    |proj g|=  1.33486D-01
#
# At iterate   33    f= -1.61228D+00    |proj g|=  2.45316D-01
#
# At iterate   34    f= -1.61240D+00    |proj g|=  1.62765D+00
#
# At iterate   35    f= -1.61345D+00    |proj g|=  5.90599D-01
#
# At iterate   36    f= -1.61379D+00    |proj g|=  2.90031D-02
#
# At iterate   37    f= -1.61382D+00    |proj g|=  1.10480D-02
#
# At iterate   38    f= -1.61383D+00    |proj g|=  1.68725D-01
#
# At iterate   39    f= -1.61385D+00    |proj g|=  7.00588D-02
#
# At iterate   40    f= -1.61386D+00    |proj g|=  9.84670D-03
#
# At iterate   41    f= -1.61387D+00    |proj g|=  9.84173D-03
#
# At iterate   42    f= -1.61388D+00    |proj g|=  1.38964D-02
#
# At iterate   43    f= -1.61395D+00    |proj g|=  4.04820D-02
#
# At iterate   44    f= -1.61395D+00    |proj g|=  4.53496D-02
#
# At iterate   45    f= -1.61395D+00    |proj g|=  7.84970D-02
#
# At iterate   46    f= -1.61396D+00    |proj g|=  3.56694D-02
#
# At iterate   47    f= -1.61396D+00    |proj g|=  2.49158D-02
#
# At iterate   48    f= -1.61396D+00    |proj g|=  1.07032D-02
#
# At iterate   49    f= -1.61396D+00    |proj g|=  4.65716D-04
#
# At iterate   50    f= -1.61396D+00    |proj g|=  2.22977D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     50     59     52     0     2   2.230D-04  -1.614D+00
#   F =  -1.6139628772436900
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# /Users/niclaspopovic/opt/anaconda3/envs/boosting/lib/python3.10/site-packages/statsmodels/tsa/base/tsa_model.py:471: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)

# %%
# Compute MAPE of baseline model
mape_baseline = round(MAPE(df_test,'sales','ETS_baseline'),2)
print(f'MAPE: {mape_baseline}')
rmse_baseline = round(RMSE(df_test,'sales','ETS_baseline'),2)
print(f'RMSE: {rmse_baseline}')
# Out:
# MAPE: 3.01
# RMSE: 476.58

# %%
# Plot actual demand vs predicitons 
df_test.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>

# %% [markdown]
# # Bootstrapping

# %%
# Here we compute the residuals of the original training data series 
res = STL(df_training['sales'],robust=True).fit()
df_training['residuals'] = res.resid
df_training['trend'] = res.trend
df_training['seasonality'] = res.seasonal

# %%
bootstrapped_master_time_series = bootstrapping_residuals(df_training,number_of_bootstrapped_series=20)

# %%
df_bootstrapped = build_bootstrapped_df(bootstrapped_master_time_series,df_training)

# %% [markdown]
# ## Make Predictions for each Time Series

# %%
predictions = []
for i in range (0, 20):
    # Add trend & seasonality to bootstrapped series
    df_bootstrapped[f'bootstrapped_series_{i}'] += df_training['trend'] + df_training['seasonality']
    model = ETSModel(df_bootstrapped[f'bootstrapped_series_{i}'],error='add',trend='add',seasonal='add',seasonal_periods=12,freq='MS')
    model = model.fit()
    y_hat = model.forecast(steps=12)
    y_hat = np.exp(y_hat)
    predictions.append(y_hat)
df_test['ETS_bootstrapped'] = np.mean(predictions,axis=0)

# You can ignore the warning regar
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.99549D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.62082D-01    |proj g|=  1.08669D+01
#
# At iterate    2    f= -1.26648D+00    |proj g|=  3.24613D+00
#
# At iterate    3    f= -1.34132D+00    |proj g|=  1.25614D+00
#
# At iterate    4    f= -1.45527D+00    |proj g|=  2.46913D+00
#
# At iterate    5    f= -1.50895D+00    |proj g|=  1.81016D+00
#
# At iterate    6    f= -1.56327D+00    |proj g|=  3.27553D-01
#
# At iterate    7    f= -1.57465D+00    |proj g|=  1.12099D+00
#
# At iterate    8    f= -1.58497D+00    |proj g|=  4.14104D-01
#
# At iterate    9    f= -1.59490D+00    |proj g|=  3.05834D-01
#
# At iterate   10    f= -1.60113D+00    |proj g|=  2.82953D-01
#
# At iterate   11    f= -1.62819D+00    |proj g|=  1.75768D+00
#
# At iterate   12    f= -1.64178D+00    |proj g|=  5.32851D+00
#
# At iterate   13    f= -1.66149D+00    |proj g|=  1.46581D+00
#
# At iterate   14    f= -1.66485D+00    |proj g|=  4.12779D-01
#
# At iterate   15    f= -1.66616D+00    |proj g|=  1.51443D-01
#
# At iterate   16    f= -1.66802D+00    |proj g|=  5.95193D-01
#
# At iterate   17    f= -1.67113D+00    |proj g|=  8.36672D-01
#
# At iterate   18    f= -1.68433D+00    |proj g|=  1.16158D+00
#
# At iterate   19    f= -1.71215D+00    |proj g|=  1.30680D+00
#
# At iterate   20    f= -1.76948D+00    |proj g|=  6.22963D+00
#
# At iterate   21    f= -1.81484D+00    |proj g|=  2.84763D+00
#
# At iterate   22    f= -1.82811D+00    |proj g|=  1.17176D+00
#
# At iterate   23    f= -1.83135D+00    |proj g|=  3.48435D-01
#
# At iterate   24    f= -1.83384D+00    |proj g|=  9.07431D-01
#
# At iterate   25    f= -1.83591D+00    |proj g|=  1.14886D+00
#
# At iterate   26    f= -1.84073D+00    |proj g|=  3.51475D-01
#
# At iterate   27    f= -1.84290D+00    |proj g|=  1.58961D-01
#
# At iterate   28    f= -1.84615D+00    |proj g|=  5.61544D-01
#
# At iterate   29    f= -1.84788D+00    |proj g|=  1.49443D-01
#
# At iterate   30    f= -1.84949D+00    |proj g|=  2.40480D-01
#
# At iterate   31    f= -1.85163D+00    |proj g|=  1.07761D+00
#
# At iterate   32    f= -1.85436D+00    |proj g|=  1.39723D+00
#
# At iterate   33    f= -1.85980D+00    |proj g|=  1.00082D+00
#
# At iterate   34    f= -1.86363D+00    |proj g|=  8.81368D-01
#
# At iterate   35    f= -1.86454D+00    |proj g|=  9.16554D-02
#
# At iterate   36    f= -1.86665D+00    |proj g|=  4.77320D-02
#
# At iterate   37    f= -1.86713D+00    |proj g|=  7.87036D-02
#
# At iterate   38    f= -1.86746D+00    |proj g|=  1.91642D-01
#
# At iterate   39    f= -1.86772D+00    |proj g|=  5.59811D-02
#
# At iterate   40    f= -1.86784D+00    |proj g|=  5.13901D-02
#
# At iterate   41    f= -1.86796D+00    |proj g|=  1.36643D-01
#
# At iterate   42    f= -1.86810D+00    |proj g|=  1.31834D-01
#
# At iterate   43    f= -1.86827D+00    |proj g|=  2.02691D-01
#
# At iterate   44    f= -1.86882D+00    |proj g|=  1.46901D-01
#
# At iterate   45    f= -1.87057D+00    |proj g|=  3.27235D-02
#
# At iterate   46    f= -1.87087D+00    |proj g|=  3.14071D-01
#
# At iterate   47    f= -1.87155D+00    |proj g|=  7.13555D-02
#
# At iterate   48    f= -1.87175D+00    |proj g|=  5.73819D-02
#
# At iterate   49    f= -1.87179D+00    |proj g|=  3.11705D-02
#
# At iterate   50    f= -1.87181D+00    |proj g|=  2.19783D-02
#
# At iterate   51    f= -1.87181D+00    |proj g|=  1.07666D-02
#
# At iterate   52    f= -1.87181D+00    |proj g|=  7.53317D-03
#
# At iterate   53    f= -1.87182D+00    |proj g|=  2.41565D-03
#
# At iterate   54    f= -1.87182D+00    |proj g|=  4.54237D-04
#
# At iterate   55    f= -1.87182D+00    |proj g|=  2.94165D-04
#
# At iterate   56    f= -1.87182D+00    |proj g|=  1.04272D-04
#
# At iterate   57    f= -1.87182D+00    |proj g|=  1.34337D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     57     66     59     0     0   1.343D-04  -1.872D+00
#   F =  -1.8718169158246165
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.84481D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.85513D-01    |proj g|=  1.08555D+01
#
# At iterate    2    f= -1.23563D+00    |proj g|=  4.10361D+00
#
# At iterate    3    f= -1.32272D+00    |proj g|=  1.75905D+00
#
# At iterate    4    f= -1.42455D+00    |proj g|=  2.63421D+00
#
# At iterate    5    f= -1.48106D+00    |proj g|=  2.13186D+00
#
# At iterate    6    f= -1.57209D+00    |proj g|=  4.07591D-01
#
# At iterate    7    f= -1.59155D+00    |proj g|=  1.24540D+00
#
# At iterate    8    f= -1.60133D+00    |proj g|=  6.13779D-01
#
# At iterate    9    f= -1.61388D+00    |proj g|=  1.27770D+00
#
# At iterate   10    f= -1.61853D+00    |proj g|=  7.59087D-01
#
# At iterate   11    f= -1.61945D+00    |proj g|=  5.23333D-01
#
# At iterate   12    f= -1.62161D+00    |proj g|=  2.50973D-01
#
# At iterate   13    f= -1.62418D+00    |proj g|=  4.63952D-01
#
# At iterate   14    f= -1.63180D+00    |proj g|=  1.36764D+00
#
# At iterate   15    f= -1.64508D+00    |proj g|=  1.91190D+00
#
# At iterate   16    f= -1.66264D+00    |proj g|=  1.01034D+00
#
# At iterate   17    f= -1.67164D+00    |proj g|=  3.43979D-01
#
# At iterate   18    f= -1.67815D+00    |proj g|=  3.42250D-01
#
# At iterate   19    f= -1.68675D+00    |proj g|=  4.79464D-01
#
# At iterate   20    f= -1.70548D+00    |proj g|=  7.98982D-01
#
# At iterate   21    f= -1.70738D+00    |proj g|=  1.26014D+00
#
# At iterate   22    f= -1.72379D+00    |proj g|=  1.55036D+00
#
# At iterate   23    f= -1.73520D+00    |proj g|=  6.74242D-01
#
# At iterate   24    f= -1.75616D+00    |proj g|=  1.01682D+01
#
# At iterate   25    f= -1.76180D+00    |proj g|=  8.72315D-01
#
# At iterate   26    f= -1.78056D+00    |proj g|=  1.28905D+00
#
# At iterate   27    f= -1.79333D+00    |proj g|=  2.23093D+00
#
# At iterate   28    f= -1.80430D+00    |proj g|=  1.93192D+00
#
# At iterate   29    f= -1.81507D+00    |proj g|=  1.87755D+00
#
# At iterate   30    f= -1.81819D+00    |proj g|=  1.33370D+00
#
# At iterate   31    f= -1.82094D+00    |proj g|=  1.21694D+00
#
# At iterate   32    f= -1.83172D+00    |proj g|=  1.84379D+00
#
# At iterate   33    f= -1.83423D+00    |proj g|=  3.33199D+00
#
# At iterate   34    f= -1.84320D+00    |proj g|=  2.36194D+00
#
# At iterate   35    f= -1.84539D+00    |proj g|=  1.72444D-01
#
# At iterate   36    f= -1.84684D+00    |proj g|=  4.43301D-01
#
# At iterate   37    f= -1.85056D+00    |proj g|=  6.28599D-01
#
# At iterate   38    f= -1.85293D+00    |proj g|=  3.46839D-01
#
# At iterate   39    f= -1.85519D+00    |proj g|=  4.51308D-01
#
# At iterate   40    f= -1.85646D+00    |proj g|=  8.13172D-01
#
# At iterate   41    f= -1.85716D+00    |proj g|=  5.39078D-01
#
# At iterate   42    f= -1.85785D+00    |proj g|=  1.05987D-01
#
# At iterate   43    f= -1.85797D+00    |proj g|=  3.09197D-02
#
# At iterate   44    f= -1.85802D+00    |proj g|=  3.68083D-02
#
# At iterate   45    f= -1.85809D+00    |proj g|=  1.93599D-01
#
# At iterate   46    f= -1.85829D+00    |proj g|=  1.62742D-01
#
# At iterate   47    f= -1.85860D+00    |proj g|=  1.37784D-01
#
# At iterate   48    f= -1.85888D+00    |proj g|=  8.92584D-02
#
# At iterate   49    f= -1.85899D+00    |proj g|=  2.90706D-01
#
# At iterate   50    f= -1.85913D+00    |proj g|=  6.30857D-02
#
# At iterate   51    f= -1.85918D+00    |proj g|=  6.56617D-02
#
# At iterate   52    f= -1.85918D+00    |proj g|=  1.15410D-02
#
# At iterate   53    f= -1.85920D+00    |proj g|=  1.89813D-02
#
# At iterate   54    f= -1.85921D+00    |proj g|=  3.53396D-02
#
# At iterate   55    f= -1.85923D+00    |proj g|=  1.07334D-02
#
# At iterate   56    f= -1.85926D+00    |proj g|=  6.35717D-02
#
# At iterate   57    f= -1.85926D+00    |proj g|=  1.89944D-02
#
# At iterate   58    f= -1.85927D+00    |proj g|=  1.09071D-02
#
# At iterate   59    f= -1.85927D+00    |proj g|=  1.38004D-02
#
# At iterate   60    f= -1.85928D+00    |proj g|=  3.11198D-02
#
# At iterate   61    f= -1.86166D+00    |proj g|=  1.83283D+00
#   ys=-6.138E-03  -gs= 9.277E-05 BFGS update SKIPPED
#
# At iterate   62    f= -1.86172D+00    |proj g|=  2.95112D-01
#
# At iterate   63    f= -1.86196D+00    |proj g|=  4.04075D-02
#
# At iterate   64    f= -1.86208D+00    |proj g|=  5.72713D-02
#
# At iterate   65    f= -1.86216D+00    |proj g|=  3.34539D-02
#
# At iterate   66    f= -1.86217D+00    |proj g|=  1.07701D-01
#
# At iterate   67    f= -1.86220D+00    |proj g|=  3.59121D-02
#
# At iterate   68    f= -1.86222D+00    |proj g|=  1.06361D-02
#
# At iterate   69    f= -1.86222D+00    |proj g|=  3.10317D-02
#
# At iterate   70    f= -1.86223D+00    |proj g|=  3.37038D-02
#
# At iterate   71    f= -1.86223D+00    |proj g|=  3.51383D-02
#
# At iterate   72    f= -1.86224D+00    |proj g|=  1.10961D-02
#
# At iterate   73    f= -1.86224D+00    |proj g|=  3.84643D-03
#
# At iterate   74    f= -1.86224D+00    |proj g|=  4.11156D-03
#
# At iterate   75    f= -1.86224D+00    |proj g|=  1.03621D-02
#
# At iterate   76    f= -1.86224D+00    |proj g|=  4.36349D-03
#
# At iterate   77    f= -1.86224D+00    |proj g|=  4.82039D-03
#
# At iterate   78    f= -1.86224D+00    |proj g|=  6.98819D-04
#
# At iterate   79    f= -1.86224D+00    |proj g|=  1.35114D-03
#
# At iterate   80    f= -1.86224D+00    |proj g|=  8.21085D-03
#
# At iterate   81    f= -1.86224D+00    |proj g|=  5.95761D-03
#
# At iterate   82    f= -1.86224D+00    |proj g|=  1.61597D-03
#
# At iterate   83    f= -1.86224D+00    |proj g|=  2.46603D-04
#
# At iterate   84    f= -1.86224D+00    |proj g|=  1.49076D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     84    101     86     1     1   1.491D-02  -1.862D+00
#   F =  -1.8622370367221701
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.91376D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.40021D-01    |proj g|=  1.06500D+01
#
# At iterate    2    f= -1.23082D+00    |proj g|=  2.96092D+00
#
# At iterate    3    f= -1.29594D+00    |proj g|=  1.14026D+00
#
# At iterate    4    f= -1.39448D+00    |proj g|=  2.26063D+00
#
# At iterate    5    f= -1.44704D+00    |proj g|=  1.85729D+00
#
# At iterate    6    f= -1.52441D+00    |proj g|=  1.48938D+00
#
# At iterate    7    f= -1.53637D+00    |proj g|=  5.44115D-01
#
# At iterate    8    f= -1.54202D+00    |proj g|=  2.21489D-01
#
# At iterate    9    f= -1.54764D+00    |proj g|=  8.81592D-01
#
# At iterate   10    f= -1.54992D+00    |proj g|=  3.28766D-01
#
# At iterate   11    f= -1.55111D+00    |proj g|=  1.16174D+00
#
# At iterate   12    f= -1.55359D+00    |proj g|=  1.65115D-01
#
# At iterate   13    f= -1.55543D+00    |proj g|=  4.41302D-01
#
# At iterate   14    f= -1.56323D+00    |proj g|=  1.47588D+00
#
# At iterate   15    f= -1.57380D+00    |proj g|=  1.98350D+00
#
# At iterate   16    f= -1.58749D+00    |proj g|=  1.82029D+00
#
# At iterate   17    f= -1.61973D+00    |proj g|=  6.81557D-01
#
# At iterate   18    f= -1.64075D+00    |proj g|=  1.32458D+00
#
# At iterate   19    f= -1.65130D+00    |proj g|=  2.01594D-01
#
# At iterate   20    f= -1.67381D+00    |proj g|=  2.75837D+00
#
# At iterate   21    f= -1.68910D+00    |proj g|=  2.87179D+00
#
# At iterate   22    f= -1.69407D+00    |proj g|=  5.56904D+00
#
# At iterate   23    f= -1.72178D+00    |proj g|=  3.15511D+00
#
# At iterate   24    f= -1.72913D+00    |proj g|=  1.33130D+00
#
# At iterate   25    f= -1.73230D+00    |proj g|=  1.68148D-01
#
# At iterate   26    f= -1.73382D+00    |proj g|=  1.61920D-01
#
# At iterate   27    f= -1.73922D+00    |proj g|=  1.39438D+00
#
# At iterate   28    f= -1.74238D+00    |proj g|=  3.83867D+00
#
# At iterate   29    f= -1.74483D+00    |proj g|=  3.81237D-01
#
# At iterate   30    f= -1.74710D+00    |proj g|=  1.93894D+00
#
# At iterate   31    f= -1.75062D+00    |proj g|=  1.17876D+00
#
# At iterate   32    f= -1.75337D+00    |proj g|=  9.96777D-01
#
# At iterate   33    f= -1.75716D+00    |proj g|=  2.39300D+00
#
# At iterate   34    f= -1.76211D+00    |proj g|=  1.52255D-01
#
# At iterate   35    f= -1.76993D+00    |proj g|=  1.02805D+00
#
# At iterate   36    f= -1.78498D+00    |proj g|=  7.48086D+00
#
# At iterate   37    f= -1.79259D+00    |proj g|=  2.99753D+00
#
# At iterate   38    f= -1.79490D+00    |proj g|=  1.74839D+00
#
# At iterate   39    f= -1.79509D+00    |proj g|=  7.24870D-01
#
# At iterate   40    f= -1.79518D+00    |proj g|=  2.07053D-01
#
# At iterate   41    f= -1.79546D+00    |proj g|=  2.24597D-01
#
# At iterate   42    f= -1.79624D+00    |proj g|=  2.86885D+00
#
# At iterate   43    f= -1.79786D+00    |proj g|=  4.40757D+00
#
# At iterate   44    f= -1.80279D+00    |proj g|=  7.59211D+00
#
# At iterate   45    f= -1.80835D+00    |proj g|=  7.68380D+00
#
# At iterate   46    f= -1.80852D+00    |proj g|=  1.08677D+01
#
# At iterate   47    f= -1.81570D+00    |proj g|=  6.80137D+00
#
# At iterate   48    f= -1.81926D+00    |proj g|=  3.08265D+00
#
# At iterate   49    f= -1.82046D+00    |proj g|=  3.07137D+00
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   50    f= -1.82047D+00    |proj g|=  2.50247D+00
#
# At iterate   51    f= -1.82119D+00    |proj g|=  1.68698D+00
#
# At iterate   52    f= -1.82274D+00    |proj g|=  1.89837D-01
#
# At iterate   53    f= -1.82350D+00    |proj g|=  2.58377D-01
#
# At iterate   54    f= -1.82536D+00    |proj g|=  1.07126D-01
#
# At iterate   55    f= -1.82621D+00    |proj g|=  5.82150D-01
#
# At iterate   56    f= -1.82652D+00    |proj g|=  1.69923D-01
#
# At iterate   57    f= -1.82663D+00    |proj g|=  8.89610D-01
#
# At iterate   58    f= -1.82667D+00    |proj g|=  1.05536D-01
#
# At iterate   59    f= -1.82670D+00    |proj g|=  1.73621D-01
#
# At iterate   60    f= -1.82672D+00    |proj g|=  2.91234D-01
#
# At iterate   61    f= -1.82672D+00    |proj g|=  1.11209D-01
#
# At iterate   62    f= -1.82672D+00    |proj g|=  6.63691D-02
#
# At iterate   63    f= -1.82672D+00    |proj g|=  1.15660D-02
#
# At iterate   64    f= -1.82672D+00    |proj g|=  5.31431D-02
#
# At iterate   65    f= -1.82672D+00    |proj g|=  6.11747D-02
#
# At iterate   66    f= -1.82673D+00    |proj g|=  4.15898D-02
#
# At iterate   67    f= -1.82673D+00    |proj g|=  8.82505D-02
#
# At iterate   68    f= -1.82673D+00    |proj g|=  6.01850D-03
#
# At iterate   69    f= -1.82673D+00    |proj g|=  3.10949D-02
#
# At iterate   70    f= -1.82673D+00    |proj g|=  1.95290D-02
#
# At iterate   71    f= -1.82673D+00    |proj g|=  3.43247D-02
#
# At iterate   72    f= -1.82673D+00    |proj g|=  1.20939D-02
#
# At iterate   73    f= -1.82673D+00    |proj g|=  2.98383D-01
#
# At iterate   74    f= -1.82674D+00    |proj g|=  2.21422D-02
#
# At iterate   75    f= -1.82674D+00    |proj g|=  8.75761D-02
#
# At iterate   76    f= -1.82674D+00    |proj g|=  1.38641D-01
#
# At iterate   77    f= -1.82674D+00    |proj g|=  9.97770D-02
#
# At iterate   78    f= -1.82674D+00    |proj g|=  4.20316D-02
#
# At iterate   79    f= -1.82674D+00    |proj g|=  2.40491D-02
#
# At iterate   80    f= -1.82674D+00    |proj g|=  1.53748D-02
#
# At iterate   81    f= -1.82674D+00    |proj g|=  3.31015D-02
#
# At iterate   82    f= -1.82674D+00    |proj g|=  1.77875D-02
#
# At iterate   83    f= -1.82674D+00    |proj g|=  2.91707D-03
#
# At iterate   84    f= -1.82674D+00    |proj g|=  1.01579D-02
#
# At iterate   85    f= -1.82674D+00    |proj g|=  4.14571D-03
#
# At iterate   86    f= -1.82674D+00    |proj g|=  2.84704D-02
#
# At iterate   87    f= -1.82674D+00    |proj g|=  1.44901D-02
#
# At iterate   88    f= -1.82674D+00    |proj g|=  8.26290D-03
#
# At iterate   89    f= -1.82674D+00    |proj g|=  1.75362D-02
#
# At iterate   90    f= -1.82674D+00    |proj g|=  4.90950D-03
#
# At iterate   91    f= -1.82674D+00    |proj g|=  2.60498D-03
#
# At iterate   92    f= -1.82674D+00    |proj g|=  1.28933D-02
#
# At iterate   93    f= -1.82674D+00    |proj g|=  1.69432D-02
#
# At iterate   94    f= -1.82674D+00    |proj g|=  3.23274D-02
#
# At iterate   95    f= -1.82674D+00    |proj g|=  2.83942D-02
#
# At iterate   96    f= -1.82674D+00    |proj g|=  6.18332D-02
#
# At iterate   97    f= -1.82674D+00    |proj g|=  2.73479D-02
#
# At iterate   98    f= -1.82674D+00    |proj g|=  2.64654D-02
#
# At iterate   99    f= -1.82674D+00    |proj g|=  3.76217D-03
#
# At iterate  100    f= -1.82674D+00    |proj g|=  2.47087D-03
#
# At iterate  101    f= -1.82674D+00    |proj g|=  6.60401D-03
#
# At iterate  102    f= -1.82674D+00    |proj g|=  7.02385D-03
#
# At iterate  103    f= -1.82674D+00    |proj g|=  5.29021D-04
#
# At iterate  104    f= -1.82674D+00    |proj g|=  3.60223D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16    104    121    106     0     1   3.602D-04  -1.827D+00
#   F =  -1.8267444222176057
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.48978D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.87003D-01    |proj g|=  1.11903D+01
#
# At iterate    2    f= -1.29680D+00    |proj g|=  3.36145D+00
#
# At iterate    3    f= -1.37067D+00    |proj g|=  1.12586D+00
#
# At iterate    4    f= -1.47355D+00    |proj g|=  2.34613D+00
#
# At iterate    5    f= -1.52424D+00    |proj g|=  1.67071D+00
#
# At iterate    6    f= -1.56978D+00    |proj g|=  4.06836D-01
#
# At iterate    7    f= -1.58076D+00    |proj g|=  1.23470D+00
#
# At iterate    8    f= -1.58969D+00    |proj g|=  3.04075D-01
#
# At iterate    9    f= -1.59739D+00    |proj g|=  2.92385D-01
#
# At iterate   10    f= -1.60346D+00    |proj g|=  3.85863D-01
#
# At iterate   11    f= -1.62065D+00    |proj g|=  7.54819D-01
#
# At iterate   12    f= -1.64038D+00    |proj g|=  3.63877D+00
#
# At iterate   13    f= -1.64928D+00    |proj g|=  7.79270D-01
#
# At iterate   14    f= -1.65504D+00    |proj g|=  2.35863D-01
#
# At iterate   15    f= -1.65850D+00    |proj g|=  1.49162D-01
#
# At iterate   16    f= -1.66410D+00    |proj g|=  4.99993D-01
#
# At iterate   17    f= -1.67485D+00    |proj g|=  1.04543D+00
#
# At iterate   18    f= -1.68204D+00    |proj g|=  5.26079D-01
#
# At iterate   19    f= -1.69541D+00    |proj g|=  6.00221D+00
#
# At iterate   20    f= -1.69778D+00    |proj g|=  6.60275D-01
#
# At iterate   21    f= -1.69888D+00    |proj g|=  7.17695D-01
#
# At iterate   22    f= -1.71198D+00    |proj g|=  6.50835D-01
#
# At iterate   23    f= -1.71656D+00    |proj g|=  2.16309D-01
#
# At iterate   24    f= -1.71939D+00    |proj g|=  3.11217D-01
#
# At iterate   25    f= -1.72672D+00    |proj g|=  2.21119D-01
#
# At iterate   26    f= -1.75194D+00    |proj g|=  1.05617D+00
#
# At iterate   27    f= -1.76181D+00    |proj g|=  2.39015D-01
#
# At iterate   28    f= -1.76661D+00    |proj g|=  3.15419D-01
#
# At iterate   29    f= -1.76940D+00    |proj g|=  9.23869D-01
#
# At iterate   30    f= -1.77075D+00    |proj g|=  1.59395D+00
#
# At iterate   31    f= -1.77169D+00    |proj g|=  7.40717D+00
#
# At iterate   32    f= -1.77503D+00    |proj g|=  1.45820D+00
#
# At iterate   33    f= -1.78251D+00    |proj g|=  7.97655D+00
#
# At iterate   34    f= -1.78947D+00    |proj g|=  9.14416D+00
#
# At iterate   35    f= -1.79248D+00    |proj g|=  4.65067D+00
#
# At iterate   36    f= -1.79326D+00    |proj g|=  2.50709D+00
#
# At iterate   37    f= -1.79366D+00    |proj g|=  4.80642D-01
#
# At iterate   38    f= -1.79377D+00    |proj g|=  3.91557D-02
#
# At iterate   39    f= -1.79392D+00    |proj g|=  3.48604D-01
#
# At iterate   40    f= -1.79415D+00    |proj g|=  2.26601D-01
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   41    f= -1.79420D+00    |proj g|=  1.29084D-01
#
# At iterate   42    f= -1.79431D+00    |proj g|=  1.07824D+00
#
# At iterate   43    f= -1.79443D+00    |proj g|=  1.25940D+00
#
# At iterate   44    f= -1.79448D+00    |proj g|=  1.52339D-01
#
# At iterate   45    f= -1.79450D+00    |proj g|=  3.64561D-02
#
# At iterate   46    f= -1.79450D+00    |proj g|=  3.52876D-02
#
# At iterate   47    f= -1.79471D+00    |proj g|=  8.95111D-01
#
# At iterate   48    f= -1.79488D+00    |proj g|=  3.64521D-01
#
# At iterate   49    f= -1.79491D+00    |proj g|=  1.01059D-02
#
# At iterate   50    f= -1.79491D+00    |proj g|=  5.50786D-02
#
# At iterate   51    f= -1.79492D+00    |proj g|=  1.45582D-01
#
# At iterate   52    f= -1.79492D+00    |proj g|=  2.22649D-01
#
# At iterate   53    f= -1.79493D+00    |proj g|=  1.50510D-01
#
# At iterate   54    f= -1.79493D+00    |proj g|=  3.48681D-01
#
# At iterate   55    f= -1.79494D+00    |proj g|=  6.43833D-02
#
# At iterate   56    f= -1.79494D+00    |proj g|=  3.26115D-02
#
# At iterate   57    f= -1.79494D+00    |proj g|=  1.54375D-02
#
# At iterate   58    f= -1.79494D+00    |proj g|=  1.79736D-02
#
# At iterate   59    f= -1.79494D+00    |proj g|=  6.40550D-03
#
# At iterate   60    f= -1.79494D+00    |proj g|=  4.71008D-03
#
# At iterate   61    f= -1.79494D+00    |proj g|=  1.64221D-02
#
# At iterate   62    f= -1.79494D+00    |proj g|=  3.51683D-02
#
# At iterate   63    f= -1.79494D+00    |proj g|=  5.32009D-02
#
# At iterate   64    f= -1.79494D+00    |proj g|=  5.71752D-02
#
# At iterate   65    f= -1.79494D+00    |proj g|=  4.74794D-02
#
# At iterate   66    f= -1.79494D+00    |proj g|=  2.91654D-02
#
# At iterate   67    f= -1.79494D+00    |proj g|=  4.31846D-03
#
# At iterate   68    f= -1.79494D+00    |proj g|=  1.15292D-02
#
# At iterate   69    f= -1.79494D+00    |proj g|=  2.14194D-02
#
# At iterate   70    f= -1.79494D+00    |proj g|=  2.84945D-02
#
# At iterate   71    f= -1.79494D+00    |proj g|=  2.08878D-02
#
# At iterate   72    f= -1.79494D+00    |proj g|=  4.10815D-02
#
# At iterate   73    f= -1.79494D+00    |proj g|=  1.30424D-02
#
# At iterate   74    f= -1.79494D+00    |proj g|=  7.64893D-03
#
# At iterate   75    f= -1.79494D+00    |proj g|=  1.39908D-02
#
# At iterate   76    f= -1.79494D+00    |proj g|=  1.15705D-02
#
# At iterate   77    f= -1.79494D+00    |proj g|=  3.16616D-02
#
# At iterate   78    f= -1.79494D+00    |proj g|=  4.89107D-03
#
# At iterate   79    f= -1.79494D+00    |proj g|=  2.71712D-02
#
# At iterate   80    f= -1.79494D+00    |proj g|=  9.99954D-02
#
# At iterate   81    f= -1.79494D+00    |proj g|=  6.44482D-02
#
# At iterate   82    f= -1.79494D+00    |proj g|=  1.22516D-01
#
# At iterate   83    f= -1.79494D+00    |proj g|=  3.53408D-02
#
# At iterate   84    f= -1.79494D+00    |proj g|=  1.10421D-02
#
# At iterate   85    f= -1.79494D+00    |proj g|=  2.91249D-02
#
# At iterate   86    f= -1.79495D+00    |proj g|=  4.53964D-02
#
# At iterate   87    f= -1.79495D+00    |proj g|=  3.05713D-02
#
# At iterate   88    f= -1.79495D+00    |proj g|=  2.79713D-02
#
# At iterate   89    f= -1.79495D+00    |proj g|=  3.38065D-03
#
# At iterate   90    f= -1.79495D+00    |proj g|=  6.62914D-04
#
# At iterate   91    f= -1.79495D+00    |proj g|=  3.29508D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     91    105     94     0     1   3.295D-03  -1.795D+00
#   F =  -1.7949453383383589
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.75562D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.85484D-01    |proj g|=  1.06521D+01
#
# At iterate    2    f= -1.16948D+00    |proj g|=  4.41045D+00
#
# At iterate    3    f= -1.25638D+00    |proj g|=  1.99950D+00
#
# At iterate    4    f= -1.33218D+00    |proj g|=  2.30599D+00
#
# At iterate    5    f= -1.37597D+00    |proj g|=  1.81854D+00
#
# At iterate    6    f= -1.47119D+00    |proj g|=  4.19321D-01
# At iterate    7    f= -1.49436D+00    |proj g|=  3.80174D-01
#
# At iterate    8    f= -1.50739D+00    |proj g|=  6.67885D-01
#
# At iterate    9    f= -1.52050D+00    |proj g|=  2.26533D-01
#
# At iterate   10    f= -1.52927D+00    |proj g|=  8.23357D-01
#
# At iterate   11    f= -1.53131D+00    |proj g|=  1.28322D+00
#
# At iterate   12    f= -1.53332D+00    |proj g|=  3.72455D-01
#
# At iterate   13    f= -1.53584D+00    |proj g|=  1.31228D-01
#
# At iterate   14    f= -1.54245D+00    |proj g|=  1.35995D+00
#
# At iterate   15    f= -1.54863D+00    |proj g|=  1.40556D+00
#
# At iterate   16    f= -1.56633D+00    |proj g|=  1.39620D+00
#
# At iterate   17    f= -1.58931D+00    |proj g|=  6.67863D-01
#
# At iterate   18    f= -1.60830D+00    |proj g|=  2.29992D+00
#
# At iterate   19    f= -1.62308D+00    |proj g|=  4.70812D+00
#
# At iterate   20    f= -1.62475D+00    |proj g|=  2.03299D+00
#
# At iterate   21    f= -1.63160D+00    |proj g|=  9.95255D-01
#
# At iterate   22    f= -1.63791D+00    |proj g|=  1.70879D-01
#
# At iterate   23    f= -1.64009D+00    |proj g|=  1.64709D-01
#
# At iterate   24    f= -1.64900D+00    |proj g|=  1.62276D+00
#
# At iterate   25    f= -1.65421D+00    |proj g|=  2.11542D+00
#
# At iterate   26    f= -1.65787D+00    |proj g|=  6.01531D-01
#
# At iterate   27    f= -1.65826D+00    |proj g|=  1.19543D-01
#
# At iterate   28    f= -1.65859D+00    |proj g|=  1.88448D-01
#
# At iterate   29    f= -1.66170D+00    |proj g|=  9.18837D-01
#
# At iterate   30    f= -1.67877D+00    |proj g|=  5.26926D-01
#
# At iterate   31    f= -1.67882D+00    |proj g|=  1.00340D+00
#
# At iterate   32    f= -1.67960D+00    |proj g|=  1.67044D-01
#
# At iterate   33    f= -1.68032D+00    |proj g|=  6.40889D-01
#
# At iterate   34    f= -1.68131D+00    |proj g|=  9.30888D-01
#
# At iterate   35    f= -1.68190D+00    |proj g|=  5.81415D-01
#
# At iterate   36    f= -1.68207D+00    |proj g|=  5.09514D-02
#
# At iterate   37    f= -1.68212D+00    |proj g|=  2.41721D-01
#
# At iterate   38    f= -1.68218D+00    |proj g|=  5.48256D-01
#
# At iterate   39    f= -1.68231D+00    |proj g|=  8.85461D-01
#
# At iterate   40    f= -1.68253D+00    |proj g|=  1.03628D+00
#
# At iterate   41    f= -1.68281D+00    |proj g|=  1.41759D+00
#
# At iterate   42    f= -1.68282D+00    |proj g|=  8.20941D-01
#
# At iterate   43    f= -1.68298D+00    |proj g|=  6.36365D-01
#
# At iterate   44    f= -1.68314D+00    |proj g|=  1.31675D-01
#
# At iterate   45    f= -1.68316D+00    |proj g|=  5.40103D-02
#
# At iterate   46    f= -1.68322D+00    |proj g|=  3.16408D-01
#
# At iterate   47    f= -1.68326D+00    |proj g|=  4.25455D-01
#
# At iterate   48    f= -1.68338D+00    |proj g|=  6.12682D-01
#
# At iterate   49    f= -1.68369D+00    |proj g|=  9.17352D-01
#
# At iterate   50    f= -1.68432D+00    |proj g|=  1.11305D+00
#
# At iterate   51    f= -1.68478D+00    |proj g|=  1.40429D+00
#
# At iterate   52    f= -1.68532D+00    |proj g|=  1.64519D+00
#
# At iterate   53    f= -1.68534D+00    |proj g|=  7.25008D-01
#
# At iterate   54    f= -1.68582D+00    |proj g|=  3.63291D-01
#
# At iterate   55    f= -1.68600D+00    |proj g|=  3.83603D-02
#
# At iterate   56    f= -1.68602D+00    |proj g|=  7.88934D-02
#
# At iterate   57    f= -1.68608D+00    |proj g|=  1.82805D-01
#
# At iterate   58    f= -1.68619D+00    |proj g|=  2.77104D-01
#
# At iterate   59    f= -1.68644D+00    |proj g|=  7.89663D-01
#
# At iterate   60    f= -1.68700D+00    |proj g|=  7.99940D-01
#
# At iterate   61    f= -1.68702D+00    |proj g|=  8.86400D-01
#
# At iterate   62    f= -1.68832D+00    |proj g|=  7.29517D-01
#
# At iterate   63    f= -1.68967D+00    |proj g|=  7.27344D-01
#
# At iterate   64    f= -1.68967D+00    |proj g|=  6.31479D-01
#
# At iterate   65    f= -1.69091D+00    |proj g|=  9.84231D-02
#
# At iterate   66    f= -1.69184D+00    |proj g|=  3.91199D-01
#
# At iterate   67    f= -1.69223D+00    |proj g|=  6.16502D-01
#
# At iterate   68    f= -1.69240D+00    |proj g|=  2.21005D-01
#
# At iterate   69    f= -1.69271D+00    |proj g|=  2.60684D-01
#
# At iterate   70    f= -1.69288D+00    |proj g|=  3.57828D-01
#
# At iterate   71    f= -1.69338D+00    |proj g|=  4.29659D-01
#
# At iterate   72    f= -1.69448D+00    |proj g|=  3.30729D+00
#
# At iterate   73    f= -1.69676D+00    |proj g|=  8.38483D-01
#
# At iterate   74    f= -1.69769D+00    |proj g|=  9.79290D-01
#
# At iterate   75    f= -1.69792D+00    |proj g|=  1.42055D+00
#
# At iterate   76    f= -1.69806D+00    |proj g|=  1.01576D+00
#
# At iterate   77    f= -1.69813D+00    |proj g|=  9.58478D-02
#
# At iterate   78    f= -1.69813D+00    |proj g|=  5.48789D-02
#
# At iterate   79    f= -1.69814D+00    |proj g|=  7.85759D-02
#
# At iterate   80    f= -1.69817D+00    |proj g|=  4.70360D-01
#
# At iterate   81    f= -1.69821D+00    |proj g|=  6.38713D-01
#
# At iterate   82    f= -1.69829D+00    |proj g|=  3.79537D-01
#
# At iterate   83    f= -1.69833D+00    |proj g|=  7.22787D-01
#
# At iterate   84    f= -1.69839D+00    |proj g|=  3.82698D-02
#
# At iterate   85    f= -1.69842D+00    |proj g|=  5.11017D-01
#
# At iterate   86    f= -1.69845D+00    |proj g|=  6.60603D-01
#
# At iterate   87    f= -1.69848D+00    |proj g|=  9.65865D-01
#
# At iterate   88    f= -1.69851D+00    |proj g|=  8.37148D-02
#
# At iterate   89    f= -1.69858D+00    |proj g|=  5.27355D-01
#
# At iterate   90    f= -1.69872D+00    |proj g|=  8.05931D-01
#
# At iterate   91    f= -1.70247D+00    |proj g|=  4.49972D-01
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   92    f= -1.70248D+00    |proj g|=  4.62063D-01
#
# At iterate   93    f= -1.70262D+00    |proj g|=  2.73598D+00
#
# At iterate   94    f= -1.70629D+00    |proj g|=  3.21834D+00
#
# At iterate   95    f= -1.71018D+00    |proj g|=  1.33240D+00
#
# At iterate   96    f= -1.71253D+00    |proj g|=  3.84173D-01
#
# At iterate   97    f= -1.71384D+00    |proj g|=  2.49735D-01
#
# At iterate   98    f= -1.71509D+00    |proj g|=  9.24636D-01
#
# At iterate   99    f= -1.71562D+00    |proj g|=  4.70516D-01
#
# At iterate  100    f= -1.71574D+00    |proj g|=  3.71430D-02
#
# At iterate  101    f= -1.71577D+00    |proj g|=  1.10468D-01
#
# At iterate  102    f= -1.71581D+00    |proj g|=  2.38650D-01
#
# At iterate  103    f= -1.71583D+00    |proj g|=  2.09556D-01
#
# At iterate  104    f= -1.71583D+00    |proj g|=  3.13780D-02
#
# At iterate  105    f= -1.71584D+00    |proj g|=  3.01595D-02
#
# At iterate  106    f= -1.71585D+00    |proj g|=  2.55023D-02
#
# At iterate  107    f= -1.71587D+00    |proj g|=  5.13953D-02
#
# At iterate  108    f= -1.71589D+00    |proj g|=  3.45556D-02
#
# At iterate  109    f= -1.71591D+00    |proj g|=  3.64309D-02
#
# At iterate  110    f= -1.71591D+00    |proj g|=  7.01017D-02
#
# At iterate  111    f= -1.71592D+00    |proj g|=  5.20106D-02
#
# At iterate  112    f= -1.71592D+00    |proj g|=  4.22238D-03
#
# At iterate  113    f= -1.71592D+00    |proj g|=  3.17555D-03
#
# At iterate  114    f= -1.71592D+00    |proj g|=  1.50697D-03
#
# At iterate  115    f= -1.71592D+00    |proj g|=  3.05408D-02
#
# At iterate  116    f= -1.71592D+00    |proj g|=  7.22160D-03
#
# At iterate  117    f= -1.71592D+00    |proj g|=  5.34237D-03
#
# At iterate  118    f= -1.71592D+00    |proj g|=  6.49147D-04
#
# At iterate  119    f= -1.71592D+00    |proj g|=  4.31855D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16    119    148    121     0     2   4.319D-04  -1.716D+00
#   F =  -1.7159218226428936
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.01276D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.54090D-01    |proj g|=  1.06950D+01
#
# At iterate    2    f= -1.23992D+00    |proj g|=  3.20245D+00
#
# At iterate    3    f= -1.31312D+00    |proj g|=  1.28758D+00
#
# At iterate    4    f= -1.43024D+00    |proj g|=  2.56165D+00
#
# At iterate    5    f= -1.49186D+00    |proj g|=  2.07525D+00
#
# At iterate    6    f= -1.57699D+00    |proj g|=  5.27154D-01
#
# At iterate    7    f= -1.58945D+00    |proj g|=  1.54253D+00
#
# At iterate    8    f= -1.59785D+00    |proj g|=  4.31396D-01
#
# At iterate    9    f= -1.60559D+00    |proj g|=  6.22768D-01
#
# At iterate   10    f= -1.61792D+00    |proj g|=  2.48494D-01
#
# At iterate   11    f= -1.62746D+00    |proj g|=  3.38595D-01
#
# At iterate   12    f= -1.64223D+00    |proj g|=  3.27809D+00
#
# At iterate   13    f= -1.64561D+00    |proj g|=  5.06282D+00
#
# At iterate   14    f= -1.66028D+00    |proj g|=  3.29506D-01
#
# At iterate   15    f= -1.66217D+00    |proj g|=  3.40202D-01
#
# At iterate   16    f= -1.66543D+00    |proj g|=  2.69277D-01
#
# At iterate   17    f= -1.69292D+00    |proj g|=  1.81786D-01
#
# At iterate   18    f= -1.71196D+00    |proj g|=  8.23636D-01
#
# At iterate   19    f= -1.75033D+00    |proj g|=  7.13430D+00
#
# At iterate   20    f= -1.75195D+00    |proj g|=  4.11779D+00
#
# At iterate   21    f= -1.76253D+00    |proj g|=  1.44426D+00
#
# At iterate   22    f= -1.76716D+00    |proj g|=  1.56638D+00
#
# At iterate   23    f= -1.76804D+00    |proj g|=  9.76317D-01
#
# At iterate   24    f= -1.77382D+00    |proj g|=  1.76902D-01
#
# At iterate   25    f= -1.78144D+00    |proj g|=  2.19351D+00
#
# At iterate   26    f= -1.78391D+00    |proj g|=  1.50157D+00
#
# At iterate   27    f= -1.78671D+00    |proj g|=  6.82570D-01
#
# At iterate   28    f= -1.78820D+00    |proj g|=  1.36808D+00
#
# At iterate   29    f= -1.78873D+00    |proj g|=  4.33531D-01
#
# At iterate   30    f= -1.78874D+00    |proj g|=  3.74647D-01
#   Positive dir derivative in projection
#   Using the backtracking step
#
# At iterate   31    f= -1.78925D+00    |proj g|=  3.28490D+00
#
# At iterate   32    f= -1.78982D+00    |proj g|=  5.21813D-01
#
# At iterate   33    f= -1.78996D+00    |proj g|=  3.52275D-01
#
# At iterate   34    f= -1.79000D+00    |proj g|=  3.27962D-01
#
# At iterate   35    f= -1.79265D+00    |proj g|=  1.05534D+00
#
# At iterate   36    f= -1.80340D+00    |proj g|=  1.91823D-01
#
# At iterate   37    f= -1.81762D+00    |proj g|=  1.61653D+00
#
# At iterate   38    f= -1.83198D+00    |proj g|=  1.87342D-01
#
# At iterate   39    f= -1.84066D+00    |proj g|=  2.18253D+00
#
# At iterate   40    f= -1.84652D+00    |proj g|=  3.42956D+00
#
# At iterate   41    f= -1.85064D+00    |proj g|=  2.47842D+00
#
# At iterate   42    f= -1.85096D+00    |proj g|=  2.03427D+00
#
# At iterate   43    f= -1.85157D+00    |proj g|=  1.34032D+00
#
# At iterate   44    f= -1.85168D+00    |proj g|=  2.62043D-01
#
# At iterate   45    f= -1.85169D+00    |proj g|=  9.20002D-02
#
# At iterate   46    f= -1.85171D+00    |proj g|=  1.87542D-01
#
# At iterate   47    f= -1.85174D+00    |proj g|=  2.09977D-01
#
# At iterate   48    f= -1.85230D+00    |proj g|=  1.45427D+00
#
# At iterate   49    f= -1.85353D+00    |proj g|=  2.65472D+00
# At iterate   50    f= -1.85478D+00    |proj g|=  2.47227D+00
#
# At iterate   51    f= -1.85547D+00    |proj g|=  4.54345D-01
#
# At iterate   52    f= -1.85561D+00    |proj g|=  2.94092D-01
#
# At iterate   53    f= -1.85562D+00    |proj g|=  9.05176D-02
#
# At iterate   54    f= -1.85564D+00    |proj g|=  2.83261D-01
#
# At iterate   55    f= -1.85566D+00    |proj g|=  3.35731D-01
#
# At iterate   56    f= -1.85569D+00    |proj g|=  1.60413D+00
#
# At iterate   57    f= -1.85576D+00    |proj g|=  5.35797D-01
#
# At iterate   58    f= -1.85579D+00    |proj g|=  1.33454D-01
#
# At iterate   59    f= -1.85581D+00    |proj g|=  6.48153D-02
#
# At iterate   60    f= -1.85582D+00    |proj g|=  3.11973D-02
#
# At iterate   61    f= -1.85583D+00    |proj g|=  1.08235D-02
#
# At iterate   62    f= -1.85583D+00    |proj g|=  8.49327D-02
#
# At iterate   63    f= -1.85583D+00    |proj g|=  4.84663D-02
#
# At iterate   64    f= -1.85583D+00    |proj g|=  1.94186D-02
#
# At iterate   65    f= -1.85583D+00    |proj g|=  3.86758D-02
#
# At iterate   66    f= -1.85583D+00    |proj g|=  6.20715D-03
#
# At iterate   67    f= -1.85583D+00    |proj g|=  5.48833D-02
#
# At iterate   68    f= -1.85583D+00    |proj g|=  9.61647D-02
#
# At iterate   69    f= -1.85583D+00    |proj g|=  4.19844D-03
#
# At iterate   70    f= -1.85583D+00    |proj g|=  4.03457D-03
#
# At iterate   71    f= -1.85583D+00    |proj g|=  4.64841D-02
#
# At iterate   72    f= -1.85584D+00    |proj g|=  6.69830D-02
#
# At iterate   73    f= -1.85584D+00    |proj g|=  8.39991D-02
#
# At iterate   74    f= -1.85584D+00    |proj g|=  3.83080D-02
#
# At iterate   75    f= -1.85584D+00    |proj g|=  2.47732D-02
#
# At iterate   76    f= -1.85584D+00    |proj g|=  7.40896D-03
#
# At iterate   77    f= -1.85584D+00    |proj g|=  5.34692D-03
#
# At iterate   78    f= -1.85584D+00    |proj g|=  2.73219D-02
#
# At iterate   79    f= -1.85584D+00    |proj g|=  7.25110D-02
#
# At iterate   80    f= -1.85584D+00    |proj g|=  3.05322D-02
#
# At iterate   81    f= -1.85584D+00    |proj g|=  1.51197D-02
#
# At iterate   82    f= -1.85584D+00    |proj g|=  4.22156D-03
#
# At iterate   83    f= -1.85584D+00    |proj g|=  3.70024D-03
#
# At iterate   84    f= -1.85584D+00    |proj g|=  1.70684D-02
#
# At iterate   85    f= -1.85584D+00    |proj g|=  1.41039D-02
#
# At iterate   86    f= -1.85584D+00    |proj g|=  2.81157D-02
#
# At iterate   87    f= -1.85584D+00    |proj g|=  1.87379D-03
#
# At iterate   88    f= -1.85584D+00    |proj g|=  1.48737D-03
#
# At iterate   89    f= -1.85584D+00    |proj g|=  2.61351D-03
#
# At iterate   90    f= -1.85584D+00    |proj g|=  2.24649D-02
#
# At iterate   91    f= -1.85584D+00    |proj g|=  1.88328D-02
#
# At iterate   92    f= -1.85584D+00    |proj g|=  3.46112D-03
#
# At iterate   93    f= -1.85584D+00    |proj g|=  8.53926D-03
#
# At iterate   94    f= -1.85584D+00    |proj g|=  9.14619D-03
#
# At iterate   95    f= -1.85584D+00    |proj g|=  1.19309D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     95    113     97     0     1   1.193D-02  -1.856D+00
#   F =  -1.8558394399650444
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.43733D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -8.40209D-01    |proj g|=  1.15866D+01
#
# At iterate    2    f= -1.29181D+00    |proj g|=  4.91480D+00
#
# At iterate    3    f= -1.38532D+00    |proj g|=  1.88018D+00
#
# At iterate    4    f= -1.46213D+00    |proj g|=  2.44699D+00
#
# At iterate    5    f= -1.50524D+00    |proj g|=  1.85956D+00
#
# At iterate    6    f= -1.56209D+00    |proj g|=  3.05119D-01
#
# At iterate    7    f= -1.57816D+00    |proj g|=  7.53066D-01
#
# At iterate    8    f= -1.58862D+00    |proj g|=  7.47441D-01
#
# At iterate    9    f= -1.61146D+00    |proj g|=  5.35199D-01
#
# At iterate   10    f= -1.61822D+00    |proj g|=  1.53742D+00
#
# At iterate   11    f= -1.62032D+00    |proj g|=  6.15800D-01
#
# At iterate   12    f= -1.62188D+00    |proj g|=  2.86818D-01
#
# At iterate   13    f= -1.63210D+00    |proj g|=  7.66216D-01
#
# At iterate   14    f= -1.64307D+00    |proj g|=  8.82115D-01
#
# At iterate   15    f= -1.66080D+00    |proj g|=  1.01683D+00
#
# At iterate   16    f= -1.68394D+00    |proj g|=  8.01421D-01
#
# At iterate   17    f= -1.70717D+00    |proj g|=  4.72506D-01
#
# At iterate   18    f= -1.74210D+00    |proj g|=  4.22059D-01
#
# At iterate   19    f= -1.77780D+00    |proj g|=  4.33068D-01
#
# At iterate   20    f= -1.81103D+00    |proj g|=  4.83394D-01
#
# At iterate   21    f= -1.81193D+00    |proj g|=  4.41109D-01
#
# At iterate   22    f= -1.81930D+00    |proj g|=  1.86471D+00
#
# At iterate   23    f= -1.83203D+00    |proj g|=  3.77761D-01
#
# At iterate   24    f= -1.83259D+00    |proj g|=  2.96189D-01
#
# At iterate   25    f= -1.83319D+00    |proj g|=  4.60037D-02
#
# At iterate   26    f= -1.83343D+00    |proj g|=  1.33035D-01
#
# At iterate   27    f= -1.83391D+00    |proj g|=  2.29211D-01
#
# At iterate   28    f= -1.83441D+00    |proj g|=  5.70462D-02
#
# At iterate   29    f= -1.83453D+00    |proj g|=  3.51427D-02
#
# At iterate   30    f= -1.83455D+00    |proj g|=  1.30759D-02
#
# At iterate   31    f= -1.83458D+00    |proj g|=  3.50218D-02
#
# At iterate   32    f= -1.83459D+00    |proj g|=  2.67952D-02
#
# At iterate   33    f= -1.83460D+00    |proj g|=  3.20375D-02
#
# At iterate   34    f= -1.83460D+00    |proj g|=  1.46513D-02
#
# At iterate   35    f= -1.83460D+00    |proj g|=  1.71120D-02
#
# At iterate   36    f= -1.83461D+00    |proj g|=  1.98604D-02
#
# At iterate   37    f= -1.83462D+00    |proj g|=  1.00097D-02
#
# At iterate   38    f= -1.83464D+00    |proj g|=  4.66435D-02
#
# At iterate   39    f= -1.83468D+00    |proj g|=  3.34595D-02
#
# At iterate   40    f= -1.83473D+00    |proj g|=  5.28319D-02
#
# At iterate   41    f= -1.83477D+00    |proj g|=  1.12070D-01
#
# At iterate   42    f= -1.83478D+00    |proj g|=  1.47638D-02
#
# At iterate   43    f= -1.83478D+00    |proj g|=  8.81077D-03
#
# At iterate   44    f= -1.83479D+00    |proj g|=  1.12287D-02
#
# At iterate   45    f= -1.83479D+00    |proj g|=  2.30831D-02
#
# At iterate   46    f= -1.83479D+00    |proj g|=  1.55328D-02
#
# At iterate   47    f= -1.83479D+00    |proj g|=  2.96556D-03
#
# At iterate   48    f= -1.83479D+00    |proj g|=  5.34801D-03
#
# At iterate   49    f= -1.83479D+00    |proj g|=  7.30052D-03
#
# At iterate   50    f= -1.83479D+00    |proj g|=  4.79916D-03
#
# At iterate   51    f= -1.83479D+00    |proj g|=  5.68923D-04
#
# At iterate   52    f= -1.83479D+00    |proj g|=  8.40328D-04
#
# At iterate   53    f= -1.83479D+00    |proj g|=  8.75167D-04
#
# At iterate   54    f= -1.83479D+00    |proj g|=  3.18279D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     54     64     57     0     0   3.183D-04  -1.835D+00
#   F =  -1.8347909276864232
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.07598D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.14044D-01    |proj g|=  1.05327D+01
#
# At iterate    2    f= -1.24223D+00    |proj g|=  2.06905D+00
#
# At iterate    3    f= -1.30273D+00    |proj g|=  7.50864D-01
#
# At iterate    4    f= -1.44673D+00    |proj g|=  1.89801D+00
#
# At iterate    5    f= -1.50948D+00    |proj g|=  4.30276D-01
#
# At iterate    6    f= -1.53403D+00    |proj g|=  9.70538D-01
#
# At iterate    7    f= -1.54424D+00    |proj g|=  3.37482D-01
#
# At iterate    8    f= -1.55826D+00    |proj g|=  2.03016D-01
#
# At iterate    9    f= -1.57721D+00    |proj g|=  5.27525D-01
#
# At iterate   10    f= -1.59303D+00    |proj g|=  7.58602D-01
#
# At iterate   11    f= -1.59515D+00    |proj g|=  1.49370D+00
#
# At iterate   12    f= -1.59770D+00    |proj g|=  9.69681D-01
#
# At iterate   13    f= -1.60151D+00    |proj g|=  4.34995D-01
#
# At iterate   14    f= -1.61393D+00    |proj g|=  1.41729D+00
#
# At iterate   15    f= -1.62337D+00    |proj g|=  1.20477D+00
#
# At iterate   16    f= -1.63752D+00    |proj g|=  6.09507D-01
#
# At iterate   17    f= -1.64827D+00    |proj g|=  1.56149D-01
#
# At iterate   18    f= -1.65678D+00    |proj g|=  3.27456D-01
#
# At iterate   19    f= -1.67402D+00    |proj g|=  6.00785D-01
#
# At iterate   20    f= -1.70500D+00    |proj g|=  7.47300D-01
#
# At iterate   21    f= -1.72572D+00    |proj g|=  1.67350D+00
#
# At iterate   22    f= -1.73435D+00    |proj g|=  5.44025D-01
#
# At iterate   23    f= -1.74533D+00    |proj g|=  2.52867D+00
#
# At iterate   24    f= -1.75204D+00    |proj g|=  2.06710D+00
#
# At iterate   25    f= -1.75861D+00    |proj g|=  1.71244D+00
#
# At iterate   26    f= -1.76312D+00    |proj g|=  2.16782D+00
#
# At iterate   27    f= -1.77020D+00    |proj g|=  4.70481D-01
#
# At iterate   28    f= -1.77267D+00    |proj g|=  1.48608D-01
#
# At iterate   29    f= -1.77529D+00    |proj g|=  1.70851D+00
#
# At iterate   30    f= -1.77581D+00    |proj g|=  1.89335D+00
#
# At iterate   31    f= -1.77699D+00    |proj g|=  7.92840D-01
#
# At iterate   32    f= -1.77753D+00    |proj g|=  2.21570D-01
#
# At iterate   33    f= -1.77868D+00    |proj g|=  5.04020D-01
#
# At iterate   34    f= -1.78036D+00    |proj g|=  9.69064D-01
#
# At iterate   35    f= -1.78218D+00    |proj g|=  9.21277D-01
#
# At iterate   36    f= -1.79732D+00    |proj g|=  6.84498D-01
#
# At iterate   37    f= -1.80910D+00    |proj g|=  6.31065D+00
#
# At iterate   38    f= -1.81228D+00    |proj g|=  2.10876D+00
#
# At iterate   39    f= -1.81248D+00    |proj g|=  1.33868D+00
#
# At iterate   40    f= -1.81254D+00    |proj g|=  5.56834D-01
#
# At iterate   41    f= -1.81257D+00    |proj g|=  1.17060D-01
#
# At iterate   42    f= -1.81259D+00    |proj g|=  1.26386D-01
#
# At iterate   43    f= -1.81266D+00    |proj g|=  5.37705D-01
#
# At iterate   44    f= -1.81275D+00    |proj g|=  8.05768D-01
#
# At iterate   45    f= -1.81304D+00    |proj g|=  1.02372D+00
#
# At iterate   46    f= -1.81367D+00    |proj g|=  1.48849D+00
#
# At iterate   47    f= -1.81524D+00    |proj g|=  1.33160D-01
#
# At iterate   48    f= -1.81715D+00    |proj g|=  7.06448D-01
#
# At iterate   49    f= -1.81727D+00    |proj g|=  3.23090D+00
#
# At iterate   50    f= -1.81905D+00    |proj g|=  8.16149D-01
#
# At iterate   51    f= -1.81933D+00    |proj g|=  3.10732D+00
#
# At iterate   52    f= -1.81976D+00    |proj g|=  7.24760D-01
#
# At iterate   53    f= -1.81988D+00    |proj g|=  7.94356D-02
#
# At iterate   54    f= -1.82006D+00    |proj g|=  4.02442D-01
#
# At iterate   55    f= -1.82008D+00    |proj g|=  1.20817D-01
#
# At iterate   56    f= -1.82010D+00    |proj g|=  3.62981D-02
#
# At iterate   57    f= -1.82011D+00    |proj g|=  3.50315D-02
#
# At iterate   58    f= -1.82013D+00    |proj g|=  1.74626D-01
#
# At iterate   59    f= -1.82020D+00    |proj g|=  5.97183D-02
#
# At iterate   60    f= -1.82033D+00    |proj g|=  1.67366D-01
#
# At iterate   61    f= -1.82036D+00    |proj g|=  5.70555D-01
#
# At iterate   62    f= -1.82044D+00    |proj g|=  4.42063D-01
#
# At iterate   63    f= -1.82050D+00    |proj g|=  2.59918D-01
#
# At iterate   64    f= -1.82051D+00    |proj g|=  5.09787D-01
#
# At iterate   65    f= -1.82052D+00    |proj g|=  6.49196D-02
#
# At iterate   66    f= -1.82052D+00    |proj g|=  3.55143D-02
#
# At iterate   67    f= -1.82052D+00    |proj g|=  1.16327D-02
#
# At iterate   68    f= -1.82052D+00    |proj g|=  3.06037D-02
#
# At iterate   69    f= -1.82052D+00    |proj g|=  4.15903D-02
#
# At iterate   70    f= -1.82052D+00    |proj g|=  1.46847D-02
#
# ...
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.44272D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.72951D-01    |proj g|=  1.06595D+01
#
# At iterate    2    f= -1.19104D+00    |proj g|=  4.22270D+00
#
# At iterate    3    f= -1.27998D+00    |proj g|=  1.97393D+00
#
# At iterate    4    f= -1.37399D+00    |proj g|=  2.69970D+00
#
# At iterate    5    f= -1.42575D+00    |proj g|=  1.96922D+00
#
# At iterate    6    f= -1.50660D+00    |proj g|=  4.49514D-01
#
# At iterate    7    f= -1.52421D+00    |proj g|=  1.94908D-01
#
# At iterate    8    f= -1.54225D+00    |proj g|=  1.30442D+00
#
# At iterate    9    f= -1.55409D+00    |proj g|=  2.84077D-01
#
# At iterate   10    f= -1.56316D+00    |proj g|=  1.19193D+00
#
# At iterate   11    f= -1.56662D+00    |proj g|=  7.83078D-01
#
# At iterate   12    f= -1.56670D+00    |proj g|=  5.84759D-01
#
# At iterate   13    f= -1.56795D+00    |proj g|=  2.27962D-01
#
# At iterate   14    f= -1.56950D+00    |proj g|=  2.85310D-01
#
# At iterate   15    f= -1.57370D+00    |proj g|=  1.11088D+00
#
# At iterate   16    f= -1.58267D+00    |proj g|=  2.08012D+00
#
# At iterate   17    f= -1.59620D+00    |proj g|=  8.32488D-01
#
# At iterate   18    f= -1.60135D+00    |proj g|=  4.42437D-01
#
# At iterate   19    f= -1.60893D+00    |proj g|=  3.47092D-01
#
# At iterate   20    f= -1.63986D+00    |proj g|=  3.94836D-01
#
# At iterate   21    f= -1.66420D+00    |proj g|=  1.14293D+01
#
# At iterate   22    f= -1.66818D+00    |proj g|=  5.18909D+00
#
# At iterate   23    f= -1.67301D+00    |proj g|=  1.49956D+00
#
# At iterate   24    f= -1.68072D+00    |proj g|=  2.75687D+00
#
# At iterate   25    f= -1.68546D+00    |proj g|=  2.32299D+00
#
# At iterate   26    f= -1.68913D+00    |proj g|=  5.33332D-01
#
# At iterate   27    f= -1.69136D+00    |proj g|=  8.80063D-01
#
# At iterate   28    f= -1.69645D+00    |proj g|=  2.59956D+00
#
# At iterate   29    f= -1.70577D+00    |proj g|=  4.36143D+00
#
# At iterate   30    f= -1.71070D+00    |proj g|=  4.80464D-01
#
# At iterate   31    f= -1.72773D+00    |proj g|=  9.58308D-01
#
# At iterate   32    f= -1.74410D+00    |proj g|=  2.08915D+00
#
# At iterate   33    f= -1.74526D+00    |proj g|=  2.51629D+00
#
# At iterate   34    f= -1.75623D+00    |proj g|=  2.41633D+00
#
# At iterate   35    f= -1.79205D+00    |proj g|=  2.90232D+00
#
# At iterate   36    f= -1.79529D+00    |proj g|=  6.08451D-01
#
# At iterate   37    f= -1.80629D+00    |proj g|=  3.93716D+00
#
# At iterate   38    f= -1.80973D+00    |proj g|=  1.52606D+00
#
# At iterate   39    f= -1.81142D+00    |proj g|=  6.76723D-01
#
# At iterate   40    f= -1.81196D+00    |proj g|=  2.15837D+00
#
# At iterate   41    f= -1.81274D+00    |proj g|=  1.60818D-01
#
# At iterate   42    f= -1.81298D+00    |proj g|=  3.31976D-01
#
# At iterate   43    f= -1.81320D+00    |proj g|=  3.59838D-01
#
# At iterate   44    f= -1.81333D+00    |proj g|=  1.62013D-01
#
# At iterate   45    f= -1.81355D+00    |proj g|=  3.31330D-01
#
# At iterate   46    f= -1.81409D+00    |proj g|=  4.39392D-01
#
# At iterate   47    f= -1.81626D+00    |proj g|=  3.26927D-01
#
# At iterate   48    f= -1.82415D+00    |proj g|=  2.03818D+00
#
# At iterate   49    f= -1.82596D+00    |proj g|=  1.93432D+00
#
# At iterate   50    f= -1.82966D+00    |proj g|=  8.21689D-01
#
# At iterate   51    f= -1.83684D+00    |proj g|=  1.45264D+00
#
# At iterate   52    f= -1.83689D+00    |proj g|=  2.33535D+00
#
# At iterate   53    f= -1.84110D+00    |proj g|=  5.87239D-01
#
# At iterate   54    f= -1.84532D+00    |proj g|=  1.16508D+00
#
# At iterate   55    f= -1.84630D+00    |proj g|=  3.68865D-01
#
# At iterate   56    f= -1.84734D+00    |proj g|=  4.31697D-01
#
# At iterate   57    f= -1.84852D+00    |proj g|=  9.74878D-01
#
# At iterate   58    f= -1.84892D+00    |proj g|=  1.21612D+00
#
# At iterate   59    f= -1.84916D+00    |proj g|=  1.48043D+00
#
# At iterate   60    f= -1.84918D+00    |proj g|=  1.04185D+00
#
# At iterate   61    f= -1.84940D+00    |proj g|=  1.90477D-01
#
# At iterate   62    f= -1.84955D+00    |proj g|=  6.04599D-01
#
# At iterate   63    f= -1.84956D+00    |proj g|=  4.56638D-02
#
# At iterate   64    f= -1.84957D+00    |proj g|=  4.89438D-02
#
# At iterate   65    f= -1.84993D+00    |proj g|=  2.97854D-01
#
# At iterate   66    f= -1.84996D+00    |proj g|=  1.14788D-02
#
# At iterate   67    f= -1.84996D+00    |proj g|=  3.75049D-02
#
# At iterate   68    f= -1.84996D+00    |proj g|=  4.72683D-02
#
# At iterate   69    f= -1.84996D+00    |proj g|=  1.60003D-03
#
# At iterate   70    f= -1.84996D+00    |proj g|=  5.90505D-04
#
# At iterate   71    f= -1.84996D+00    |proj g|=  2.22582D-02
#
# At iterate   72    f= -1.84996D+00    |proj g|=  1.09551D-02
#
# At iterate   73    f= -1.84996D+00    |proj g|=  8.46190D-04
#
# At iterate   74    f= -1.84996D+00    |proj g|=  1.28687D-02
#
# At iterate   75    f= -1.84996D+00    |proj g|=  6.31917D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     75     93     77     0     1   6.319D-04  -1.850D+00
#   F =  -1.8499618683249504
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -1.94039D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -7.34046D-01    |proj g|=  1.05056D+01
#
# At iterate    2    f= -1.20455D+00    |proj g|=  2.95164D+00
#
# At iterate    3    f= -1.26566D+00    |proj g|=  1.18937D+00
#
# At iterate    4    f= -1.35113D+00    |proj g|=  2.02354D+00
#
# At iterate    5    f= -1.39493D+00    |proj g|=  1.69761D+00
#
# At iterate    6    f= -1.45844D+00    |proj g|=  8.17995D-01
#
# At iterate    7    f= -1.46890D+00    |proj g|=  1.03998D+00
#
# At iterate    8    f= -1.48132D+00    |proj g|=  8.42971D-01
#
# At iterate    9    f= -1.49371D+00    |proj g|=  4.04172D-01
#
# At iterate   10    f= -1.50133D+00    |proj g|=  2.59718D+00
#
# At iterate   11    f= -1.50343D+00    |proj g|=  1.19537D+00
#
# At iterate   12    f= -1.50759D+00    |proj g|=  2.40651D-01
#
# At iterate   13    f= -1.51027D+00    |proj g|=  6.79800D-01
#
# At iterate   14    f= -1.51494D+00    |proj g|=  1.12060D+00
#
# At iterate   15    f= -1.52016D+00    |proj g|=  7.20185D-01
#
# At iterate   16    f= -1.52383D+00    |proj g|=  2.38732D-01
#
# At iterate   17    f= -1.52847D+00    |proj g|=  3.83995D-01
#
# At iterate   18    f= -1.53300D+00    |proj g|=  7.81416D-01
#
# At iterate   19    f= -1.53980D+00    |proj g|=  1.04000D+00
#
# At iterate   20    f= -1.55191D+00    |proj g|=  1.81875D+00
#
# At iterate   21    f= -1.55569D+00    |proj g|=  3.31951D-01
#
# At iterate   22    f= -1.56449D+00    |proj g|=  4.26165D-01
#
# At iterate   23    f= -1.56716D+00    |proj g|=  3.55139D+00
#
# At iterate   24    f= -1.56926D+00    |proj g|=  1.08799D+00
#
# At iterate   25    f= -1.57214D+00    |proj g|=  2.49806D-01
#
# At iterate   26    f= -1.57338D+00    |proj g|=  1.26384D+00
#
# At iterate   27    f= -1.57561D+00    |proj g|=  1.19045D+00
#
# At iterate   28    f= -1.58025D+00    |proj g|=  2.73214D+00
#
# At iterate   29    f= -1.59008D+00    |proj g|=  2.31602D-01
#
# At iterate   30    f= -1.59329D+00    |proj g|=  2.70717D-01
#
# At iterate   31    f= -1.59661D+00    |proj g|=  1.44174D+00
#
# At iterate   32    f= -1.61185D+00    |proj g|=  4.59217D-01
#
# At iterate   33    f= -1.62089D+00    |proj g|=  6.87362D+00
#
# At iterate   34    f= -1.63144D+00    |proj g|=  3.48428D+00
#
# At iterate   35    f= -1.63994D+00    |proj g|=  1.05540D+01
#
# At iterate   36    f= -1.64209D+00    |proj g|=  2.05390D+00
#
# At iterate   37    f= -1.64419D+00    |proj g|=  1.19852D+00
#
# At iterate   38    f= -1.64652D+00    |proj g|=  2.03754D+00
#
# At iterate   39    f= -1.64689D+00    |proj g|=  1.91121D+00
#
# At iterate   40    f= -1.64753D+00    |proj g|=  2.98034D-01
#
# At iterate   41    f= -1.64771D+00    |proj g|=  1.24155D-01
#
# At iterate   42    f= -1.64811D+00    |proj g|=  9.84003D-01
#
# At iterate   43    f= -1.64836D+00    |proj g|=  1.22701D+00
#
# At iterate   44    f= -1.64869D+00    |proj g|=  2.69384D-01
#
# At iterate   45    f= -1.64883D+00    |proj g|=  1.30400D-01
#
# At iterate   46    f= -1.64896D+00    |proj g|=  1.29908D-01
#
# At iterate   47    f= -1.64897D+00    |proj g|=  6.50634D-01
#
# At iterate   48    f= -1.64968D+00    |proj g|=  1.16199D+00
#
# At iterate   49    f= -1.65075D+00    |proj g|=  1.50544D+00
#
# At iterate   50    f= -1.65408D+00    |proj g|=  2.37180D+00
#
# At iterate   51    f= -1.65530D+00    |proj g|=  1.46526D+00
#
# At iterate   52    f= -1.66061D+00    |proj g|=  1.96758D+00
#
# At iterate   53    f= -1.66295D+00    |proj g|=  2.59584D+00
#
# At iterate   54    f= -1.66789D+00    |proj g|=  1.82907D+00
#
# At iterate   55    f= -1.67280D+00    |proj g|=  8.93377D-01
#
# At iterate   56    f= -1.67461D+00    |proj g|=  9.50016D-02
#
# At iterate   57    f= -1.67482D+00    |proj g|=  7.82272D-02
#
# At iterate   58    f= -1.67483D+00    |proj g|=  5.55596D-01
#
# At iterate   59    f= -1.67491D+00    |proj g|=  4.57903D-01
#
# At iterate   60    f= -1.67619D+00    |proj g|=  6.02640D-02
#
# At iterate   61    f= -1.67750D+00    |proj g|=  2.34995D-01
#
# At iterate   62    f= -1.67755D+00    |proj g|=  2.93556D-02
#
# At iterate   63    f= -1.67766D+00    |proj g|=  6.37122D-02
#
# At iterate   64    f= -1.67769D+00    |proj g|=  1.62846D-01
#
# At iterate   65    f= -1.67773D+00    |proj g|=  6.43731D-02
#
# At iterate   66    f= -1.67779D+00    |proj g|=  8.57304D-02
#
# At iterate   67    f= -1.67781D+00    |proj g|=  7.81128D-02
#
# At iterate   68    f= -1.67783D+00    |proj g|=  8.69820D-03
#
# At iterate   69    f= -1.67783D+00    |proj g|=  1.41885D-01
#
# At iterate   70    f= -1.67783D+00    |proj g|=  5.48124D-02
#
# At iterate   71    f= -1.67783D+00    |proj g|=  3.18910D-02
#
# At iterate   72    f= -1.67783D+00    |proj g|=  7.17226D-04
#
# At iterate   73    f= -1.67783D+00    |proj g|=  5.29865D-04
#
# At iterate   74    f= -1.67783D+00    |proj g|=  1.06970D-03
#
# At iterate   75    f= -1.67783D+00    |proj g|=  1.96030D-03
#
# At iterate   76    f= -1.67783D+00    |proj g|=  1.81637D-03
#
# At iterate   77    f= -1.67783D+00    |proj g|=  1.45319D-03
#
# At iterate   78    f= -1.67783D+00    |proj g|=  6.40887D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     78     96     82     0     1   6.409D-04  -1.678D+00
#   F =  -1.6778332456563028
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =           16     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f= -2.28567D-01    |proj g|=  9.88789D-01
#
# At iterate    1    f= -8.09593D-01    |proj g|=  1.13834D+01
#
# At iterate    2    f= -1.31483D+00    |proj g|=  4.05349D+00
#
# At iterate    3    f= -1.40323D+00    |proj g|=  1.44922D+00
#
# At iterate    4    f= -1.51289D+00    |proj g|=  2.74783D+00
#
# At iterate    5    f= -1.56984D+00    |proj g|=  2.00038D+00
#
# At iterate    6    f= -1.62600D+00    |proj g|=  2.56789D-01
#
# At iterate    7    f= -1.64000D+00    |proj g|=  1.19976D+00
#
# At iterate    8    f= -1.64921D+00    |proj g|=  7.92864D-01
#
# At iterate    9    f= -1.66177D+00    |proj g|=  7.28358D-01
#
# At iterate   10    f= -1.66675D+00    |proj g|=  3.47861D-01
#
# At iterate   11    f= -1.66788D+00    |proj g|=  1.20792D+00
#
# At iterate   12    f= -1.67020D+00    |proj g|=  1.76818D-01
#
# At iterate   13    f= -1.67147D+00    |proj g|=  4.35396D-01
#
# At iterate   14    f= -1.67657D+00    |proj g|=  1.26251D+00
#
# At iterate   15    f= -1.68739D+00    |proj g|=  2.00013D+00
#
# At iterate   16    f= -1.70037D+00    |proj g|=  1.75718D+00
#
# At iterate   17    f= -1.72074D+00    |proj g|=  1.65608D+00
#
# At iterate   18    f= -1.72658D+00    |proj g|=  5.24718D-01
#
# At iterate   19    f= -1.74498D+00    |proj g|=  2.19564D-01
#
# At iterate   20    f= -1.76177D+00    |proj g|=  1.02501D+00
#
# At iterate   21    f= -1.77666D+00    |proj g|=  6.74782D-01
#
# At iterate   22    f= -1.80654D+00    |proj g|=  2.77009D-01
#
# At iterate   23    f= -1.81830D+00    |proj g|=  1.30763D+00
#
# At iterate   24    f= -1.83301D+00    |proj g|=  2.86929D+00
#
# At iterate   25    f= -1.85532D+00    |proj g|=  2.42548D+00
#
# At iterate   26    f= -1.86785D+00    |proj g|=  9.11157D-01
#
# At iterate   27    f= -1.87016D+00    |proj g|=  1.85706D+00
#
# At iterate   28    f= -1.87206D+00    |proj g|=  5.17836D-01
#
# At iterate   29    f= -1.87274D+00    |proj g|=  1.46914D-01
#
# At iterate   30    f= -1.87332D+00    |proj g|=  2.86829D-01
#
# At iterate   31    f= -1.87508D+00    |proj g|=  1.13382D+00
#
# At iterate   32    f= -1.87671D+00    |proj g|=  1.20722D+00
#
# At iterate   33    f= -1.88445D+00    |proj g|=  2.29712D-01
#
# At iterate   34    f= -1.89062D+00    |proj g|=  7.10248D-01
#
# At iterate   35    f= -1.89287D+00    |proj g|=  7.18663D-01
#
# At iterate   36    f= -1.89397D+00    |proj g|=  4.97876D-01
#
# At iterate   37    f= -1.89450D+00    |proj g|=  3.87226D-01
#
# At iterate   38    f= -1.89506D+00    |proj g|=  2.16036D-02
#
# At iterate   39    f= -1.89508D+00    |proj g|=  7.69731D-02
#
# At iterate   40    f= -1.89511D+00    |proj g|=  5.35734D-02
#
# At iterate   41    f= -1.89512D+00    |proj g|=  5.74366D-02
#
# At iterate   42    f= -1.89514D+00    |proj g|=  2.65267D-02
#
# At iterate   43    f= -1.89521D+00    |proj g|=  1.87018D-02
#
# At iterate   44    f= -1.89532D+00    |proj g|=  2.93185D-02
#
# At iterate   45    f= -1.89542D+00    |proj g|=  4.63094D-02
#
# At iterate   46    f= -1.89548D+00    |proj g|=  2.43569D-01
#
# At iterate   47    f= -1.89567D+00    |proj g|=  2.38192D-01
#
# At iterate   48    f= -1.89609D+00    |proj g|=  3.13279D-01
#
# At iterate   49    f= -1.89636D+00    |proj g|=  4.98308D-01
#
# At iterate   50    f= -1.89707D+00    |proj g|=  5.57239D-01
#
# At iterate   51    f= -1.89838D+00    |proj g|=  1.34240D-01
#
# At iterate   52    f= -1.89877D+00    |proj g|=  2.17647D-01
#
# At iterate   53    f= -1.89920D+00    |proj g|=  5.40354D-01
#
# At iterate   54    f= -1.89977D+00    |proj g|=  1.73231D-01
#
# At iterate   55    f= -1.89994D+00    |proj g|=  5.28662D-02
#
# At iterate   56    f= -1.90011D+00    |proj g|=  1.92936D-02
#
# At iterate   57    f= -1.90015D+00    |proj g|=  6.50803D-02
#
# At iterate   58    f= -1.90025D+00    |proj g|=  5.84448D-02
#
# At iterate   59    f= -1.90027D+00    |proj g|=  2.71731D-02
#
# At iterate   60    f= -1.90027D+00    |proj g|=  1.41078D-03
#
# At iterate   61    f= -1.90027D+00    |proj g|=  1.19578D-03
#
# At iterate   62    f= -1.90027D+00    |proj g|=  1.64480D-03
#
# At iterate   63    f= -1.90027D+00    |proj g|=  9.56346D-04
#
# At iterate   64    f= -1.90027D+00    |proj g|=  1.63078D-03
#
# At iterate   65    f= -1.90027D+00    |proj g|=  1.17839D-04
#
# At iterate   66    f= -1.90027D+00    |proj g|=  1.47304D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#    16     66     80     68     0     0   1.473D-04  -1.900D+00
#   F =  -1.9002734064683777
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH

# %%
# Results of the bootstrapping approach
mape_bootstrapped = round(MAPE(df_test,'sales','ETS_bootstrapped'),2)
print(f'MAPE: {mape_bootstrapped}')
rmse_bootstrapped = round(RMSE(df_test,'sales','ETS_bootstrapped'),2)
print(f'RMSE: {rmse_bootstrapped}')
# Out:
# MAPE: 2.8
# RMSE: 424.0

# %%
df_test.plot()
# Out:
# <AxesSubplot:xlabel='DATE'>
